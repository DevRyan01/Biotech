# %% [markdown]
# IMPORTS

# %%
from ultralytics import YOLO
from PIL import Image

# %% [markdown]
# Trainning Model YOLO11-OBB (objects detections)

# %%
model = YOLO("yolo11m-obb.pt") #yolo11n.pt
#model = YOLO("/media/lnknick/POP-WIN/TESTE_YOUTUBE/dataset-runs/obb/train3/weights/best.pt") #yolo11n.pt
model.train(data="./data.yaml",
            epochs= 100,
            resume = False,
            patience = 10,
            batch = -1,
            imgsz = 640,
            save = True,
            device = 0,
            workers= 8,
            pretrained =False,
            box=7.5,
            cls =0.5,
            val=True,
            plots= True,
            close_mosaic = 20,
            project = "/media/lnknick/POP-WIN/TESTE_YOUTUBE/dataset-runs/obb/TrainMediumYolo11",
            auto_augment=False
                  )

# %% [markdown]
# Metrics

# %%
model = YOLO("/media/lnknick/POP-WIN/TESTE_YOUTUBE/dataset-runs/obb/TrainMediumYolo11/train4/weights/best.pt")

# %%
results = model.val(#project='runs/detect',
                    imgsz=640,
                    batch=32,
                    conf=0.001,
                    iou=0.7,  # Non-Maximum Supression (NMS)
                    save_json=False,  # Save to JSON {image_id, cls, bbox, conf} of each image in dataset  # Bounding box labels + inference on the output image (Ultralytics 8.0.178 = results are wrong when this argmunent is True)
                    split='test')  # train, val or test

print(results)

# %%
# Run inference on 'bus.jpg'
results = model("/home/lnknick/Downloads/1.jpg")  # results list

# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"results{i}.jpg")
# Out:
# image 1/1 /home/lnknick/Downloads/1.jpg: 640x640 17 Cystoisosporas, 14.9ms
# Speed: 4.5ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
